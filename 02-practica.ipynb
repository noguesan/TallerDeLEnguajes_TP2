# %% [markdown]
# # Ejercicio 1
# Explicación de la solución:
# Copiamos el Zen de Python en una variable zen_text.
#
# Dividimos el texto en líneas usando .split("\n").
#
# Filtramos solo las líneas en las que la segunda palabra comience con una vocal.
#
# Imprimimos las líneas que cumplen la condición.

# %%
# 1
import this
import codecs

zen_text = codecs.decode(this.s, "rot_13")  # *
 # *
# El Zen de Python se guarda en la variable this.s
# Utiliza el medotodo decode de codecs para decodificar el Zen de Python. que esta en "rot_13". ROT13 es un método de cifrado que reemplaza cada letra con la que está 13 posiciones adelante en el alfabeto.

print(zen_text)  # Ahora se imprime correctamente


# Lista de vocales en mayúsculas y minúsculas
vowels = "AEIOUaeiou"

print("-"*100)
# Filtramos e imprimimos las líneas cuya segunda palabra comience con vocal
for line in zen_text.split("\n"): # Dividimos el zen en líneas y recorremos cada line
    words = line.split()  # Dividimos la línea en palabras
    if  len(words) > 1 and words[1][0] in vowels:  # Verificamos que la linea tenga al menos 2 palabras y que la segunda palabra empieza con vocal
        print(line)

print("-"*100)
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
# ...

# %% [markdown]
# # Ejercicio 2

# %%
# 2
titles = [
"Speedrun de Super Mario en tiempo récord",
"Charla sobre desarrollo de videojuegos",
"Jugando al nuevo FPS del momento con amigos",
"Música en vivo: improvisaciones al piano"
]
def titulo_mas_largo(lista_titulos):
  """Recorre una lista y devuelve el elemento mas largo"""
  titulo_mas_largo = lista_titulos[0]
  for elemento in lista_titulos:
    if len(elemento) > len(titulo_mas_largo):
      titulo_mas_largo = elemento
  return titulo_mas_largo

print("El titulo mas largo es: ",titulo_mas_largo(titles))
# Out:
# el titulo mas largo es:  Jugando al nuevo FPS del momento con amigos

# %% [markdown]
# # Ejercicio 3

# %%
# 3
rules = """Respeta a los demás. No se permiten insultos ni lenguaje
ofensivo.
Evita el spam. No publiques enlaces sospechosos o repetitivos.
No compartas información personal.
Usa los canales adecuados para cada tema.
Sigue las instrucciones de los moderadores."""

def palabra_clave():
  """Solicita una palabra clave al usuario e imprima todas las reglas que la contengan."""
  palabra = input("Ingrese una palabra clave: ")
  for regla in rules.split("\n"):
    if palabra in regla:
      print(regla)

palabra_clave()
# Out:
# Ingrese una palabra clave: moderadores
# Sigue las instrucciones de los moderadores.

# %% [markdown]
# # Ejercicio 4

# %%
# 4
def validar_usuario(usuario):
  """Te dice si el usuario es valido"""

  if (len(usuario) >= 5 and # Verifica que tenga al menos 5 digitos
          any(char.isdigit() for char in usuario) and # Verifica que al menos un caracter sea un numero
          any(char.isupper() for char in usuario) and # Verifica que al menos un caracter sea una mayuscula
          all (char.isalnum() for char in usuario)): # Verifica que los caracteres sean alfanuméricos (numeros o letras mayusculas o minusculas)
          print("El nombre de usuario es válido.")
          return True
  else:
          print("El nombre de usuario no es válido.")
          return False

usuario = input("Ingrese un nombre de usuario:")
validar_usuario(usuario)
# Out:
# Ingrese un nombre de usuario:Gamer123
# El nombre de usuario es válido.
# True

# %% [markdown]
# Notas:
#   * Any(): evalúa si al menos uno de los elementos en un iterable es verdadero
#   * All():  evalúa si todos los elementos en un iterable son verdaderos

# %% [markdown]
# # Ejercicio 5

# %%
# 5
def clasificar_reaccion(time):
  """Clasifica la reacción del jugador según el tiempo de respuesta en milisegundos."""
  if time < 200:
    return "Rápido"
  elif time >= 200 and time <= 500:
    return "Normal"
  elif time > 500:
    return "Lento"
  else:
    return "Tiempo inválido"

time = int(input("Ingrese el tiempo de reacción en ms: "))
print(clasificar_reaccion(time))
# Out:
# Ingrese el tiempo de reacción en ms: 320
# Normal

# %% [markdown]
# # Ejercicio 6

# %%
# 6
descriptions = [
"Streaming de música en vivo con covers y composiciones",
"Charla interactiva con la audiencia sobre series y películas",
"Jugamos a juegos retro y charlamos sobre su historia",
"Exploramos la mejor música de los 80s y 90s",
"Programa de entretenimiento con noticias y curiosidades del mundo gamer",
"Sesión de charla con invitados especiales del mundo del streaming",
"Música en directo con improvisaciones y peticiones del chat",
"Un espacio para charlar relajada sobre tecnología y cultura digital",
"Exploramos el impacto de la música en los videojuegos clásicos"
]

def contador_mce(lista):
  """Recibe una lista y cuenta cuantas menciones hay de  "música", "charla" y "entretenimiento"."""
  musica = 0
  charla = 0
  entretenimiento = 0
  for elemento in lista:
    if "música" in elemento.lower():
        musica += 1
    if "charla" in elemento.lower():
        charla += 1
    if "entretenimiento" in elemento.lower():
        entretenimiento += 1
  return musica, charla, entretenimiento

print(contador_mce(descriptions))


# Llamada a la función y obtención de resultados
resultados = contador_mce(descriptions)

# Imprimir los resultados fuera de la función
print(f"Menciones de 'música': {resultados[0]}")
print(f"Menciones de 'charla': {resultados[1]}")
print(f"Menciones de 'entretenimiento': {resultados[2]}")
# Out:
# (4, 4, 1)
# Menciones de 'música': 4
# Menciones de 'charla': 4
# Menciones de 'entretenimiento': 1

# %% [markdown]
# Notas:
#  * Devuelve un valor de 4 en charla en lugar de 2 dado que considera las palabras charlamos y charlar por contener la palabra charla

# %% [markdown]
# # Ejercicio 7

# %%
# 7
import random
from datetime import datetime

def generar_codigo_descuento(usuario):
  """Genera un codigo de descuento en base a nombre de usuario fecha actual y un codigo al azar"""
    # Validar que el nombre de usuario no exceda los 15 caracteres
    if len(usuario) > 15:
        return "El nombre de usuario no puede exceder los 15 caracteres."

    # Obtener la fecha actual en formato 'YYYYMMDD'
    fecha_actual = datetime.now().strftime("%Y%m%d")

    # Caracteres aleatorios a generar
    caracteres_aleatorios = 30-len(usuario)-8-2 #8 son los caracteres de la fecha y 2 corresponde a los guiones de separacion

    # Generar la parte aleatoria de caracteres, que puede ser una combinación de letras y números
    caracteres_aleatorios = ''.join(random.choices('ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789', k=caracteres_aleatorios))

    # Generar el código de descuento completo
    codigo_descuento = f"{usuario.upper()}-{fecha_actual}-{caracteres_aleatorios}"

    return codigo_descuento

# Solicitar el nombre de usuario
usuario = input("Ingrese su nombre de usuario: ")

# Generar y mostrar el código de descuento
print(f"Código de descuento: ", generar_codigo_descuento(usuario))
# Out:
# Ingrese su nombre de usuario: StramPro
# Código de descuento:  STRAMPRO-20250328-2U3LXIZDUZP7

# %% [markdown]
# # Ejercicio 8

# %%
# 8
def son_anagramas(palabra1, palabra2):
    # Comparar las palabras ordenadas
    if sorted(palabra1.lower()) == sorted(palabra2.lower()):
        return "Son anagramas."
    else:
        return "No son anagramas."

# Solicitar las palabras al usuario
palabra1 = input("Ingrese la primera palabra: ")
palabra2 = input("Ingrese la segunda palabra: ")

# Llamar a la función y mostrar el resultado
print(son_anagramas(palabra1, palabra2))
# Out:
# Ingrese la primera palabra: amor
# Ingrese la segunda palabra: roma
# Son anagramas.

# %% [markdown]
# Notas
#   * sorted(palabra): Ordena las letras de la palabra alfabéticamente.

# %% [markdown]
# # Ejercicio 9

# %% [markdown]
# Notas:
#   * No lo mensiona en la consigna pero en la salida esperada muestra a los datos ordenados tambien.

# %%
# 9
def limpiar_clientes(clientes):
    # Eliminar espacios extras, convertir a formato de título y filtrar valores vacíos o None
    clientes_limpios = [cliente.strip().title() for cliente in clientes if cliente and cliente.strip()]

    # Eliminar registros duplicados utilizando un set
    clientes_limpios = list(set(clientes_limpios))

    # Ordenar la lista alfabéticamente
    clientes_limpios.sort()

    return clientes_limpios

# Lista de datos inicial
clients = [
    " Ana López ", "Pedro Gómez", "maria martínez", "Pedro Gómez ", "",
    " Luis Rodríguez ", None, "ana lópez", "JUAN PÉREZ", "MARTA SUÁREZ",
    "luis rodríguez", "maría martínez ", " claudia torres", "CLAUDIA TORRES",
    " ", "pedro gómez", "Juan Pérez", None, "Ricardo Fernández", "LAURA RAMOS",
    "carlos mendes", "RICARDO FERNÁNDEZ ", " Laura ramos", "CARLOS MENDES",
    "alejandro gonzález", " ALEJANDRO GONZÁLEZ ", "Patricia Vega",
    "patricia VEGA", "Andrés Ocampo", " andrés ocampo", "Monica Herrera",
    "MONICA HERRERA ", "gabriela ruíz", "Gabriela Ruíz", "sandra morales",
    "SANDRA MORALES", "miguel ángel", "Miguel Ángel ", " Damián Castillo",
    "Damián Castillo ", None, "", " "
]

# Limpiar la lista de clientes
clientes_limpios = limpiar_clientes(clients)

# Mostrar la lista limpia
print("Lista limpia de clientes al realizar todas las operaciones:")
print(clientes_limpios)
# Out:
# Lista limpia de clientes al realizar todas las operaciones:
# ['Alejandro González', 'Ana López', 'Andrés Ocampo', 'Carlos Mendes', 'Claudia Torres', 'Damián Castillo', 'Gabriela Ruíz', 'Juan Pérez', 'Laura Ramos', 'Luis Rodríguez', 'Maria Martínez', 'Marta Suárez', 'María Martínez', 'Miguel Ángel', 'Monica Herrera', 'Patricia Vega', 'Pedro Gómez', 'Ricardo Fernández', 'Sandra Morales']

# %% [markdown]
# # Ejercicio 10

# %%
# Definir las acciones y los puntos correspondientes
points = {
    'kill': 3,
    'death': -1
}

# Inicializar el diccionario de jugadores con estadísticas vacías
jugadores = {
    'Shadow': {'kills': 0, 'assists': 0, 'deaths': 0, 'mvp': 0, 'points': 0},
    'Blaze': {'kills': 0, 'assists': 0, 'deaths': 0, 'mvp': 0, 'points': 0},
    'Viper': {'kills': 0, 'assists': 0, 'deaths': 0, 'mvp': 0, 'points': 0},
    'Frost': {'kills': 0, 'assists': 0, 'deaths': 0, 'mvp': 0, 'points': 0},
    'Reaper': {'kills': 0, 'assists': 0, 'deaths': 0, 'mvp': 0, 'points': 0}
}

# Lista de rondas
rounds = [
    {
        'Shadow': {'kills': 2, 'assists': 1, 'deaths': True},
        'Blaze': {'kills': 1, 'assists': 0, 'deaths': False},
        'Viper': {'kills': 1, 'assists': 2, 'deaths': True},
        'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
    },
    {
        'Shadow': {'kills': 0, 'assists': 2, 'deaths': False},
        'Blaze': {'kills': 2, 'assists': 0, 'deaths': True},
        'Viper': {'kills': 1, 'assists': 1, 'deaths': False},
        'Frost': {'kills': 2, 'assists': 1, 'deaths': True},
        'Reaper': {'kills': 0, 'assists': 1, 'deaths': False}
    },
    {
        'Shadow': {'kills': 1, 'assists': 0, 'deaths': False},
        'Blaze': {'kills': 2, 'assists': 2, 'deaths': True},
        'Viper': {'kills': 1, 'assists': 1, 'deaths': True},
        'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
    },
    {
        'Shadow': {'kills': 2, 'assists': 1, 'deaths': False},
        'Blaze': {'kills': 1, 'assists': 0, 'deaths': True},
        'Viper': {'kills': 0, 'assists': 2, 'deaths': False},
        'Frost': {'kills': 1, 'assists': 1, 'deaths': True},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
    },
    {
        'Shadow': {'kills': 1, 'assists': 2, 'deaths': True},
        'Blaze': {'kills': 0, 'assists': 1, 'deaths': False},
        'Viper': {'kills': 2, 'assists': 0, 'deaths': True},
        'Frost': {'kills': 1, 'assists': 1, 'deaths': False},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': True}
    }
]

# Función para calcular el puntaje y actualizar las estadísticas
def actualizar_estadisticas(round_data):
    mvp = None
    max_puntos_ronda = float('-inf')  # Inicializamos con un valor muy bajo

    for jugador, stats in round_data.items():
        kills = stats['kills']
        assists = stats['assists']
        deaths = stats['deaths']

        # Calcular puntos de la ronda
        puntos_ronda = kills * points['kill'] + assists * points.get('assist', 0) + (points['death'] if deaths else 0)

        # Actualizar estadísticas generales
        jugadores[jugador]['kills'] += kills
        jugadores[jugador]['assists'] += assists
        jugadores[jugador]['deaths'] += 1 if deaths else 0
        jugadores[jugador]['points'] += puntos_ronda

        # Identificar al MVP de la ronda
        if mvp is None or puntos_ronda > max_puntos_ronda:
            mvp = jugador
            max_puntos_ronda = puntos_ronda  # Actualizamos el máximo de la ronda

    # Actualizar MVP
    if mvp:
        jugadores[mvp]['mvp'] += 1

    return mvp

# Función para mostrar el ranking
def mostrar_ranking():
    ranking = sorted(jugadores.items(), key=lambda x: x[1]['points'], reverse=True) # x[1] accede al diccionario de jugadores
    """
    notas de la parte del codigo x[1]['points']
    dict_items([
    ('Shadow', {'kills': 5, 'assists': 3, 'deaths': 2, 'mvp': 1, 'points': 16}),
    ('Blaze', {'kills': 7, 'assists': 2, 'deaths': 3, 'mvp': 0, 'points': 20}),
    ('Viper', {'kills': 4, 'assists': 5, 'deaths': 1, 'mvp': 2, 'points': 18})
    ])
    Cada elemento es una tupla donde:

    x[0] es el nombre del jugador (Ejemplo: "Shadow")

    x[1] es su diccionario de estadísticas
    (Ejemplo: {'kills': 5, 'assists': 3, 'deaths': 2, 'mvp': 1, 'points': 16})

    """

    print(f"{'Jugador':<10} {'Kills':<6} {'Asistencias':<12} {'Muertes':<8} {'MVPs':<5} {'Puntos':<6}")
    # :<10 -->  se alinea a la izquierda (<) y ocupa 10 espacios.
    print("-" * 50)
    for jugador, stats in ranking:
        print(f"{jugador:<10} {stats['kills']:<6} {stats['assists']:<12} {stats['deaths']:<8} {stats['mvp']:<5} {stats['points']:<6}")
    print("-" * 50)

# Simulación de las rondas
for round_num, round_data in enumerate(rounds, 1):
    # round_num recibe el número de la ronda (1, 2, 3, …).
    # round_data recibe el diccionario con las estadísticas de los jugadores en esa ronda.
    print(f"Ranking ronda {round_num}:")
    mvp = actualizar_estadisticas(round_data)
    print(f"MVP de la ronda: {mvp}\n")
    mostrar_ranking()

# Mostrar el ranking final
print("Ranking final:")
mostrar_ranking()
# Out:
# Ranking ronda 1:
# MVP de la ronda: Shadow
#
# Jugador    Kills  Asistencias  Muertes  MVPs  Puntos
# --------------------------------------------------
# Shadow     2      1            1        1     5
# Blaze      1      0            0        0     3
# Reaper     1      1            0        0     3
# Viper      1      2            1        0     2
# Frost      0      1            0        0     0
# --------------------------------------------------
# Ranking ronda 2:
# MVP de la ronda: Blaze
#
# Jugador    Kills  Asistencias  Muertes  MVPs  Puntos
# --------------------------------------------------
# Blaze      3      0            1        1     8
# Shadow     2      3            1        1     5
# Viper      2      3            1        0     5
# Frost      2      2            1        0     5
# Reaper     1      2            0        0     3
# --------------------------------------------------
# Ranking ronda 3:
# MVP de la ronda: Blaze
#
# ...

# %% [markdown]
# Notas:
#   * Linea:  for jugador, stats in round_data.items():
#       .items(): devuelve un conjunto de pares (clave, valor), donde:
#        * jugador toma el nombre del jugador (clave).
#        * stats toma el diccionario con sus estadísticas (valor).
#   * sorted: en Python se usa para ordenar listas, tuplas y otros iterables, devolviendo una nueva lista ordenada sin modificar la original.
#   sorted(iterable, key=None, reverse=False)
#     * key: (Opcional) Una función que define cómo se comparan los elementos (ejemplo: ordenar por un atributo específico).
#     * reverse: (Opcional) Si True, ordena de mayor a menor; si False (por defecto), ordena de menor a mayor.
#   *  lambda: se usa para definir funciones anónimas (es decir, funciones sin nombre) de manera concisa. Su sintaxis básica es: lambda argumentos: expresión
#     * Puede tener múltiples argumentos pero solo una expresión.
#     * No usa la palabra clave return, ya que la expresión evaluada se devuelve automáticamente.
#     * Son útiles para funciones cortas y simples, especialmente cuando se usan con funciones como map(), filter(), y sorted().
#   * enumerate(rounds, 1)
#     * enumerate() es una función de Python que agrega un índice a cada elemento de la lista.
#     * rounds es la lista que contiene los datos de las rondas.
#     * 1 indica que la numeración empieza desde 1 en lugar de 0.

# %%
# Lista de rondas
rounds = [
    {
        'Shadow': {'kills': 2, 'assists': 1, 'deaths': True},
        'Blaze': {'kills': 1, 'assists': 0, 'deaths': False},
        'Viper': {'kills': 1, 'assists': 2, 'deaths': True},
        'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
    },
    {
        'Shadow': {'kills': 0, 'assists': 2, 'deaths': False},
        'Blaze': {'kills': 2, 'assists': 0, 'deaths': True},
        'Viper': {'kills': 1, 'assists': 1, 'deaths': False},
        'Frost': {'kills': 2, 'assists': 1, 'deaths': True},
        'Reaper': {'kills': 0, 'assists': 1, 'deaths': False}
    },
    {
        'Shadow': {'kills': 1, 'assists': 0, 'deaths': False},
        'Blaze': {'kills': 2, 'assists': 2, 'deaths': True},
        'Viper': {'kills': 1, 'assists': 1, 'deaths': True},
        'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
    },
    {
        'Shadow': {'kills': 2, 'assists': 1, 'deaths': False},
        'Blaze': {'kills': 1, 'assists': 0, 'deaths': True},
        'Viper': {'kills': 0, 'assists': 2, 'deaths': False},
        'Frost': {'kills': 1, 'assists': 1, 'deaths': True},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
    },
    {
        'Shadow': {'kills': 1, 'assists': 2, 'deaths': True},
        'Blaze': {'kills': 0, 'assists': 1, 'deaths': False},
        'Viper': {'kills': 2, 'assists': 0, 'deaths': True},
        'Frost': {'kills': 1, 'assists': 1, 'deaths': False},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': True}
    }
]

# -------------------------------------------------------------------------------------

# Definir las acciones y los puntos correspondientes
points = {
    'kill': 3,
    'assist': 1,
    'death': -1
}

# Inicializar el diccionario de jugadores con estadísticas vacías
jugadores = {
    'Shadow': {'kills': 0, 'assists': 0, 'deaths': 0, 'mvp': 0, 'points': 0},
    'Blaze': {'kills': 0, 'assists': 0, 'deaths': 0, 'mvp': 0, 'points': 0},
    'Viper': {'kills': 0, 'assists': 0, 'deaths': 0, 'mvp': 0, 'points': 0},
    'Frost': {'kills': 0, 'assists': 0, 'deaths': 0, 'mvp': 0, 'points': 0},
    'Reaper': {'kills': 0, 'assists': 0, 'deaths': 0, 'mvp': 0, 'points': 0}
}

# Función para calcular el puntaje y actualizar las estadísticas
def actualizar_estadisticas(round_data):
    mvp = None
    max_puntos_ronda = float('-inf')  # Inicializamos con un valor muy bajo

    # Diccionario temporal para almacenar los valores de la ronda
    ronda_stats = {jugador: {'kills': 0, 'assists': 0, 'deaths': 0, 'points': 0} for jugador in jugadores}

    for jugador, stats in round_data.items():
        kills = stats['kills']
        assists = stats['assists']
        deaths = stats['deaths']

        # Calcular puntos de la ronda
        puntos_ronda = kills * points['kill'] + assists * points['assist'] + (points['death'] if deaths else 0)

        # Guardar estadísticas de la ronda en el diccionario temporal
        ronda_stats[jugador]['kills'] = kills
        ronda_stats[jugador]['assists'] = assists
        ronda_stats[jugador]['deaths'] = 1 if deaths else 0
        ronda_stats[jugador]['points'] = puntos_ronda

        # Identificar al MVP de la ronda
        if mvp is None or puntos_ronda > max_puntos_ronda:
            mvp = jugador
            max_puntos_ronda = puntos_ronda  # Actualizamos el máximo de la ronda

    # Mostrar ranking de la ronda antes de actualizar los valores acumulados
    mostrar_ranking(ronda_stats, f"Estadísticas de la ronda (MVP: {mvp})")

    # Actualizar estadísticas generales
    for jugador in jugadores:
        jugadores[jugador]['kills'] += ronda_stats[jugador]['kills']
        jugadores[jugador]['assists'] += ronda_stats[jugador]['assists']
        jugadores[jugador]['deaths'] += ronda_stats[jugador]['deaths']
        jugadores[jugador]['points'] += ronda_stats[jugador]['points']

    # Mostrar ranking con los valores acumulados actualizados
    mostrar_ranking(jugadores, f"Estadísticas actualizadas")

    # Actualizar MVP
    if mvp:
        jugadores[mvp]['mvp'] += 1

    return mvp

# Función para mostrar el ranking de la ronda o total
def mostrar_ranking(stats, titulo="Ranking total"):
    ranking = sorted(stats.items(), key=lambda x: x[1]['points'], reverse=True) # x[1] accede al diccionario de jugadores
    """
    notas de la parte del codigo x[1]['points']
    dict_items([
    ('Shadow', {'kills': 5, 'assists': 3, 'deaths': 2, 'mvp': 1, 'points': 16}),
    ('Blaze', {'kills': 7, 'assists': 2, 'deaths': 3, 'mvp': 0, 'points': 20}),
    ('Viper', {'kills': 4, 'assists': 5, 'deaths': 1, 'mvp': 2, 'points': 18})
    ])
    Cada elemento es una tupla donde:

    x[0] es el nombre del jugador (Ejemplo: "Shadow")

    x[1] es su diccionario de estadísticas
    (Ejemplo: {'kills': 5, 'assists': 3, 'deaths': 2, 'mvp': 1, 'points': 16})

    """

    print(f"\n{titulo}")
    print(f"{'Jugador':<10} {'Kills':<6} {'Asistencias':<12} {'Muertes':<8} {'Puntos':<6}")
    # :<10 -->  se alinea a la izquierda (<) y ocupa 10 espacios.
    print("-" * 50)
    for jugador, stat in ranking:
        print(f"{jugador:<10} {stat['kills']:<6} {stat['assists']:<12} {stat['deaths']:<8} {stat['points']:<6}")
    print("-" * 50)

# Simulación de las rondas
for round_num, round_data in enumerate(rounds, 1):
    # round_num recibe el número de la ronda (1, 2, 3, …).
    # round_data recibe el diccionario con las estadísticas de los jugadores en esa ronda.
    print(f"\nRonda {round_num}:")
    mvp = actualizar_estadisticas(round_data)

# Mostrar el ranking final con valores acumulados
print("_" * 100)
mostrar_ranking(jugadores, "Ranking final")
# Out:
# Ronda 1:
#
# Estadísticas de la ronda (MVP: Shadow)
# Jugador    Kills  Asistencias  Muertes  Puntos
# --------------------------------------------------
# Shadow     2      1            1        6
# Viper      1      2            1        4
# Reaper     1      1            0        4
# Blaze      1      0            0        3
# Frost      0      1            0        1
# --------------------------------------------------
#
# Estadísticas actualizadas
# Jugador    Kills  Asistencias  Muertes  Puntos
# --------------------------------------------------
# Shadow     2      1            1        6
# Viper      1      2            1        4
# Reaper     1      1            0        4
# Blaze      1      0            0        3
# Frost      0      1            0        1
# --------------------------------------------------
#
# Ronda 2:
#
# Estadísticas de la ronda (MVP: Frost)
# Jugador    Kills  Asistencias  Muertes  Puntos
# --------------------------------------------------
# ...
